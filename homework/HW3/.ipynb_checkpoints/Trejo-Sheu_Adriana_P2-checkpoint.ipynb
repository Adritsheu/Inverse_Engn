# %% [markdown]
# # Problem 2. Finding Neptune before seeing it.

# %% [markdown]
# https://en.wikipedia.org/wiki/Discovery_of_Neptune
#
# The planet Neptune was mathematically predicted before it was directly observed. With a prediction by Urbain Le Verrier, telescopic observations confirming the existence of a major planet were made on the night of September 23–24, 1846, at the Berlin Observatory, by astronomer Johann Gottfried Galle (assisted by Heinrich Louis d'Arrest), working from Le Verrier's calculations. It was a sensational moment of 19th-century science, and dramatic confirmation of Newtonian gravitational theory. In François Arago's apt phrase, Le Verrier had discovered a planet "with the point of his pen".
#
# In this home Problem, we are letting you to discover Neptune in a Sun-Uranus-Neptune system using `jax`. We will start with a single-planet practice

# %%
import jax.numpy as np
from jax.experimental.ode import  odeint
from jax import grad
from jax import jit
import matplotlib.pyplot as plt
import numpy as onp

# %% [markdown]
# ## Part (a)
#
# Consider a two-body Uranus-Sun system. Suppose the Uranus' orbital around sun has a farthest point with $d_{US} = 3.0$. At this point, the Uranus travels at $v_U = 4.0$. Load the data from `orbit_data_2A.txt` and use `jax` to find out what is the mass of the Sun $m_S$.
#
# The time period within which the data is simulated is between $0$ and $1.0$.

# %% [markdown]
# The two-body Newton's equation of motion written in an `odeint` compatible form

# %%
def newton_2(coord,t, m_S):
    x = coord[:2]
    y = coord[2:4]
    r = np.sqrt(x[0]**2+y[0]**2)
    ax = -(x[0]/r)*m_S/r**2
    ay = -(y[0]/r)*m_S/r**2
    return np.array([x[1], ax, y[1], ay])

# %% [markdown]
# Load the two-body data. The data is in the format of $(x, v_x, y, v_y)$ where $v$ is the velocity.

# %%
orbit_data = onp.loadtxt('./orbit_data_2A.txt')
orbit_data[0,1:]
# Out:
# array([3., 0., 0., 4.])

# %% [markdown]
# This is how the orbit looks like

# %%
plt.plot(orbit_data[:,1],orbit_data[:,3],'.--')
plt.scatter([0],[0])

# %% [markdown]
# ### Solution to (a)

# %%
# Solution here
# solve for m_s
d_us = 3.0
v_u = 4.0

t = orbit_data[:,0]
ms_guess = 900.0
coord = orbit_data[0,1:]

def loss(m_s): # (xt - xreal) ^2 + (yt - yreal) ^2
    return np.sum((odeint(newton_2,coord,t,m_s)[:,0].reshape(-1) - orbit_data[:,1].reshape(-1))**2 /
                  + ((odeint(newton_2,coord,t,m_s)[:,2].reshape(-1) - orbit_data[:,3].reshape(-1))**2))

# %%
grad_ms = jit(grad(loss,0))

lr_ms = 0.0001
count = 0

position_data = [orbit_data[:,1], orbit_data[:,3]]

# %%
while np.abs(grad_ms(ms_guess)) > 0.0001:
    ms_guess -= lr_ms * grad_ms(ms_guess)
    count +=1
    
    if count > 1000:
        break
        
    if count % 100 == 0:
        cur_traj = odeint(newton_2,coord,t,ms_guess)
        position_guess = [cur_traj[:,0],cur_traj[:,2]]
        fig, ax = plt.subplots(1,2, figsize=(12,4))
        for i, variable in enumerate(['x', 'y']):
            ax[i].plot(t, position_data[i], label=f'true {variable}')
            ax[i].plot(t, position_guess[i], label=f'learned {variable}')
            ax[i].set_xlabel('t')
            ax[i].set_ylabel(f'{variable}')
            ax[i].set_title(f'{variable} training at iteration #{count}')
            ax[i].grid()
            ax[i].legend()
        print("Guess of Sun", np.abs(ms_guess))
        print("Loss",np.abs(grad_ms(ms_guess)))
        plt.show()
    
print(f"Converged Mass of Sun {np.abs(ms_guess)} after {count} iterations with loss {np.abs(grad_ms(ms_guess))}")
# Out:
# Guess of Sun 828507.75
# Loss 15.951523
# Guess of Sun 828507.75
# Loss 15.951523
# Guess of Sun 828507.75
# Loss 15.951523
# Guess of Sun 828507.75
# Loss 15.951523
# Guess of Sun 828507.75
# Loss 15.951523
# Guess of Sun 828507.75
# Loss 15.951523
# Guess of Sun 828507.75
# Loss 15.951523
# Guess of Sun 828507.75
# Loss 15.951523
# Guess of Sun 828507.75
# Loss 15.951523
# Guess of Sun 828507.75
# Loss 15.951523
# Converged Mass of Sun 828507.75 after 1001 iterations with loss 15.951522827148438

# %% [markdown]
# ## (b) Now we consider the three body system including the Sun, Uranus and Neptune. You will be given
#
# *   A short trajectory of Uranus `orbit_data_3B.txt`. The time period within which the data is simulated is between $0$ and $0.05$.
# *   Mass $m_U$. Distance from the Uranus to the Sun at the starting point $r_{U}$.
#
# and you will predict
# *   The mass of Neptune $m_N$
# *   The distance from Neptune to the Sun at the starting point $r_{NS}$
#
# More configuration of the sustem:
# *   The Sun is fixed at $(0,0)$
# *   The starting positions of the Uranus and the Neptune are $(r_{US}, 0)$ and $(r_{NS}, 0)$.
# *   Uranus and Neptune are put quite close to each other in order for the influence between Uranus and Neptune to show up quickly.
# *   In this question, the velocities are set to $\sqrt{M/r_0}$, which is the velocity of a circular orbital when feeling only the gravity from the sun. You can find it in the following code but you do not need to do any modification.
#
# **Report your findings to Kaggle!**

# %%
m_U = 8.681 
m_S = 782.123 
r_US = 3.0

# %% [markdown]
# The two-body Newton's equation of motion written in an `odeint` compatible form

# %%
#calculation of gravity
def grav(m1,m2,r):
    return m1*m2/r**2


# newtons method
def newton_3(coord,t, m_N, r_N):
    x_U = coord[:2] # x is actually x and dx/dt
    y_U = coord[2:4] # has position & velocity
    
    # neptune
    x_N = coord[4:6]
    y_N = coord[6:8]
    
    # distance to sun
    r_U = np.sqrt(x_U[0]**2+y_U[0]**2)
    r_N = np.sqrt(x_N[0]**2+y_N[0]**2)
    
    # dist neptune to uranus
    x_UN = x_N - x_U
    y_UN = y_N - y_U    
    
    #dist uranus & neptune
    r_UN = np.sqrt((x_UN[0])**2+(y_UN[0])**2)
    
    # component force acting on Uranus in x and y direction
    fx_U = -(x_U[0]/r_U)*grav(m_U, m_S, r_U) + (x_UN[0]/r_UN)*grav(m_U, m_N, r_UN)
    fy_U = -(y_U[0]/r_U)*grav(m_U, m_S, r_U) + (y_UN[0]/r_UN)*grav(m_U, m_N, r_UN) 
    
    # force on neptune in x and y direction
    fx_N = -(x_N[0]/r_N)*grav(m_N, m_S, r_N) - (x_UN[0]/r_UN)*grav(m_U, m_N, r_UN)
    fy_N = -(y_N[0]/r_N)*grav(m_N, m_S, r_N) - (y_UN[0]/r_UN)*grav(m_U, m_N, r_UN)
    
    # return velocity_x, force/mass = acceleration
    # return first order and second order derivatives
    return np.array([x_U[1], fx_U/m_U, y_U[1], fy_U/m_U, x_N[1], fx_N/m_N, y_N[1], fy_N/m_N])

def circle_v(m_center, r0):
  # get the velocity that makes a planet's orbit a sphere. 
  # It should be a save velocity for us to use to make legitimate simulation.
    return  np.sqrt(m_center/r0)

# %% [markdown]
# The orbit data is in the format of $(time, x_U, y_U)$ where $x$ stands for the position of Uranus.

# %%
import numpy as onp

# %%
orbit_data = onp.loadtxt('./orbit_data_2B.txt')

# %% [markdown]
# See that the orbit is not closed? Because it is pulled by the Neptune.
# Now go get Neptune!

# %%
plt.plot(orbit_data[:,1],orbit_data[:,2],'.--')
plt.scatter([0],[0])

# %% [markdown]
# ### Solution to (b)

# %%
# First Solve for Initial Conditions
# know that Ux and Uy from orbit
time = orbit_data[:,0]
x_u = orbit_data[0,1]
y_u = orbit_data[0,2]

# vx = 0 given position x non zero
vx_u = 0
vy_u = circle_v(m_S,r_US) # do not have to consider the mass of uranus

ic_u = [x_u, vx_u, y_u, vy_u]
print("Initial Conditions of Uranus", ic_u)
# Out:
# Initial Conditions of Uranus [3.0, 0, 0.0, DeviceArray(16.146444, dtype=float32, weak_type=True)]

# %%
# Initial Conditions neptune
x_n = 2.0 # based off my guess
vx_n = 0
y_n = 0
vy_n = circle_v(m_S, x_n)
ic_n = [x_n, vx_n,y_n,vy_n]
print("Guess Initial Conditions of Neptune", ic_n)

mN_guess = 8.2
rN_guess = 2.0
# Out:
# Guess Initial Conditions of Neptune [2.0, 0, 0, DeviceArray(19.775274, dtype=float32, weak_type=True)]

# %%
velocity_data = onp.zeros((len(time),2))

for i in range(0,len(time)-1):
    vx = circle_v(m_S,orbit_data[i,1])
    vy = circle_v(m_S,orbit_data[i,2])
    velocity_data[i] = vx,vy
# Out:
# <ipython-input-32-a33a45782bdc>:41: RuntimeWarning: divide by zero encountered in double_scalars
#   return  np.sqrt(m_center/r0)

# %%
velocity_data
# Out:
# array([[ 16.14644432,          inf],
#        [ 16.15768623,  69.26695251],
#        [ 16.19153595,  49.01607513],
#        [ 16.24829865,  40.07180023],
#        [ 16.32853127,  34.764328  ],
#        [ 16.43301773,  31.16458893],
#        [ 16.56280518,  28.52802277],
#        [ 16.7192421 ,  26.49827194],
#        [ 16.90399933,  24.88052559],
#        [ 17.11916733,  23.55809402],
#        [ 17.36726952,  22.4562912 ],
#        [ 17.65140915,  21.52478981],
#        [ 17.97538185,  20.72829437],
#        [ 18.34383011,  20.04124641],
#        [ 18.76249123,  19.44465637],
#        [ 19.2385025 ,  18.92404938],
#        [ 19.78078651,  18.46825409],
#        [ 20.40077019,  18.06847382],
#        [ 21.11315536,  17.71771431],
#        [ 21.93728638,  17.41037178],
#        [ 22.89918709,  17.14188576],
#        [ 24.0348053 ,  16.90855598],
#        [ 25.39529991,  16.70737648],
#        [ 27.056633  ,  16.53589058],
#        [ 29.1373558 ,  16.39212227],
#        [ 31.8351059 ,  16.27448273],
#        [ 35.51073456,  16.18170738],
#        [ 40.91598892,  16.11288643],
#        [ 49.98806381,  16.06735039],
#        [ 70.33572388,  16.04470062],
#        [518.56225586,  16.04476547],
#        [         nan,  16.06764412],
#        [         nan,  16.11366653],
#        [         nan,  16.18342209],
#        [         nan,  16.27774048],
#        [         nan,  16.3978157 ],
#        [         nan,  16.54514503],
#        [         nan,  16.72161102],
#        [         nan,  16.92956352],
#        [         nan,  17.17191696],
#        [         nan,  17.45222855],
#        [         nan,  17.77492142],
#        [         nan,  18.14544296],
#        [         nan,  18.57059479],
#        [         nan,  19.05896378],
#        [         nan,  19.62144089],
#        [         nan,  20.2721405 ],
#        [         nan,  21.02972412],
#        [         nan,  21.91915131],
#        [         nan,  22.97503281],
#        [         nan,  24.24677467],
#        [         nan,  25.80784416],
#        [         nan,  27.77310371],
#        [         nan,  30.33483887],
#        [         nan,  33.8459549 ],
#        [         nan,  39.04756546],
#        [         nan,  47.87707901],
#        [         nan,  68.20444489],
#        [         nan,          nan],
#        [         nan,          nan],
#        [         nan,          nan],
#        [         nan,          nan],
#        [         nan,          nan],
#        [         nan,          nan],
#        [         nan,          nan],
#        [         nan,          nan],
#        [         nan,          nan],
#        [         nan,          nan],
#        [         nan,          nan],
#        [         nan,          nan],
#        [         nan,          nan],
#        [         nan,          nan],
#        [         nan,          nan],
#        [         nan,          nan],
#        [         nan,          nan],
#        [         nan,          nan],
#        [         nan,          nan],
#        [         nan,          nan],
#        [         nan,          nan],
#        [         nan,          nan],
#        [ 77.2027359 ,          nan],
#        [ 49.34849548,          nan],
#        [ 39.18805313,          nan],
#        [ 33.55676651,          nan],
#        [ 29.88065529,          nan],
#        [ 27.25924683,          nan],
#        [ 25.28452873,          nan],
#        [ 23.74126053,          nan],
#        [ 22.50375366,          nan],
#        [ 21.49302101,          nan],
#        [ 20.65665817,          nan],
#        [ 19.95838737,          nan],
#        [ 19.37220573,          nan],
#        [ 18.87900543,          nan],
#        [ 18.46440697,          nan],
#        [ 18.11744308,          nan],
#        [ 17.82960129,          nan],
#        [ 17.59427071,          nan],
#        [ 17.40623856,          nan],
#        [  0.        ,   0.        ]])

# %%
vel_u = np.nan_to_num(velocity_data)

# %%
coord = np.array([x_u, vx_u, y_u, vy_u,x_n, vx_n,y_n,vy_n])
t = orbit_data[:,0]

# %%
output = odeint(newton_3,coord,t,1.0,1.0)
output[0]
# Out:
# DeviceArray([ 3.      ,  0.      ,  0.      , 16.146444,  2.      ,
#               0.      ,  0.      , 19.775274], dtype=float32)

# %%
plt.plot(t, output)
plt.plot(t, vel_u[:,0])
plt.plot(t, vel_u[:,1])
plt.show()

# %%
def loss(m_N, r_N): # comparing velocity data of uranus because thats all we have
    return np.sum((odeint(newton_3,coord,t,m_N,r_N)[:,0].reshape(-1) - vel_u[:,0].reshape(-1))**2 + \
                  ((odeint(newton_3,coord,t,m_N,r_N)[:,2].reshape(-1) - vel_u[:,1].reshape(-1))**2))

# %%
loss(1.0,1.0)
# Out:
# DeviceArray(inf, dtype=float32)

# %%
grad_mN = jit(grad(loss,0))
grad_rN = jit(grad(loss,1))


lr_mN = 0.002
lr_rN = 0.003
count = 0

# %%
while np.abs(grad_mN(mN_guess,rN_guess)) > 0.01 and np.abs(grad_rN(mN_guess,rN_guess)) > 0.01 :
    mN_guess -= lr_mN * grad_mN(mN_guess,rN_guess)
    rN_guess -= lr_rN * grad_rN(mN_guess,rN_guess)
    
    count +=1
    if count > 1000:
        break
        
    if count % 100 == 0:
        cur_traj = newton_3(coord,t, mN_guess, rN_guess)
        velocity_guess = [cur_traj[:,0],cur_traj[:,2]]
        fig, ax = plt.subplots(1,2, figsize=(12,4))
        for i, variable in enumerate(['Ux', 'Uy']):
            ax[i].plot(t,vel_u[:,i], label=f'true {variable}')
            ax[i].plot(t, velocity_guess[i], label=f'learned {variable}')
            ax[i].set_xlabel('t')
            ax[i].set_ylabel(f'{variable}')
            ax[i].set_title(f'{variable} training at iteration #{count}')
            ax[i].grid()
            ax[i].legend()
        print("Guess of Sun", np.abs(ms_guess))
        print("Loss Neptune Mass",np.abs(grad_mN(mN_guess,rN_guess)))
        print("Loss Start Position of Neptune",np.abs(grad_rN(mN_guess,rN_guess)))
        plt.show()
       
    
print(f"Converged value for Mass of Neptune {np.abs(mN_guess)}")
print(f"Converged value for starting Position of Neptune {np.abs(rN_guess),0}")
print(f"This took {count} iterations")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-247-7ef20aa865fe> in <module>
# ----> 1 while np.abs(grad_mN(mN_guess,rN_guess)) > 0.01 and np.abs(grad_rN(mN_guess,rN_guess)) > 0.01 :
#       2     mN_guess -= lr_mN * grad_mN(mN_guess,rN_guess)
#       3     rN_guess -= lr_rN * grad_rN(mN_guess,rN_guess)
#       4
#       5     count +=1
#
#     [... skipping hidden 24 frame]
#
# <ipython-input-244-d61bcb2109eb> in loss(m_N, r_N)
#       1 def loss(m_N, r_N): # comparing velocity data of uranus because thats all we have
# ----> 2     return np.sum((odeint(newton_3,coord,t,m_N,r_N)[:,0].reshape(-1) - vel_u[:,1].reshape(-1))**2 /
#       3                   + ((odeint(newton_3,coord,t,m_N,r_N)[:,2].reshape(-1) - vel_u[:,2].reshape(-1))**2))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/jax/experimental/ode.py in odeint(func, y0, t, rtol, atol, mxstep, *args)
#     171     raise TypeError(f"t must be an array of floats, but got {t}.")
#     172
# --> 173   converted, consts = custom_derivatives.closure_convert(func, y0, t[0], *args)
#     174   return _odeint_wrapper(converted, rtol, atol, mxstep, y0, t, *args, *consts)
#     175
#
#     [... skipping hidden 8 frame]
#
# <ipython-input-155-a33a45782bdc> in newton_3(coord, t, m_N, r_N)
#      15     # distance to sun
#      16     r_U = np.sqrt(x_U[0]**2+y_U[0]**2)
# ---> 17     r_N = np.sqrt(x_N[0]**2+y_N[0]**2)
#      18
#      19     # dist neptune to uranus
#
#     [... skipping hidden 1 frame]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py in _rewriting_take(arr, idx, indices_are_sorted, unique_indices, mode, fill_value)
#    5751   arr = asarray(arr)
#    5752   treedef, static_idx, dynamic_idx = _split_index_for_jit(idx, arr.shape)
# -> 5753   return _gather(arr, treedef, static_idx, dynamic_idx, indices_are_sorted,
#    5754                  unique_indices, mode, fill_value)
#    5755
#
# ~/opt/anaconda3/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py in _gather(arr, treedef, static_idx, dynamic_idx, indices_are_sorted, unique_indices, mode, fill_value)
#    5760             unique_indices, mode, fill_value):
#    5761   idx = _merge_static_and_dynamic_indices(treedef, static_idx, dynamic_idx)
# -> 5762   indexer = _index_to_gather(shape(arr), idx)  # shared with _scatter_update
#    5763   y = arr
#    5764
#
# ~/opt/anaconda3/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py in _index_to_gather(x_shape, idx, normalize_indices)
#    5959       if core.symbolic_equal_dim(x_shape[x_axis], 0):
#    5960         # XLA gives error when indexing into an axis of size 0
# -> 5961         raise IndexError(f"index is out of bounds for axis {x_axis} with size 0")
#    5962       i = _normalize_index(i, x_shape[x_axis]) if normalize_indices else i
#    5963       i = lax.convert_element_type(i, index_dtype)
#
# IndexError: index is out of bounds for axis 0 with size 0
